# %%
import os
os.environ['http_proxy'] = 'http://proxy.stc:3128'
os.environ['https_proxy'] = 'https://proxy.stc:3128'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !cat yolov5/data/hyps/hyp_my.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.001  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 23-September-2023 22:14:08

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 10 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer Adam --hyp yolov5/data/hyps/hyp_my.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 24-September-2023 03:11:47

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.504      0.752       0.63      0.622
#                  Anger       2745        527      0.456      0.569      0.569      0.558
# ...

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 24-September-2023 10:58:02

# %% [markdown]
# **Experiment 2** Optimizer to SGD

# %%
# !cat yolov5/data/hyps/hyp_my-2.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.001  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 10 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer SGD --hyp yolov5/data/hyps/hyp_my-2.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my-2.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp2/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.581       0.75      0.686      0.676
#                  Anger       2745        527      0.683      0.678      0.776      0.764
# ...

# %% [markdown]
# **Experiment 3** Optimizer to AdamW

# %%
# !cat yolov5/data/hyps/hyp_my-3.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.001  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 10 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer AdamW --hyp yolov5/data/hyps/hyp_my-3.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my-3.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=AdamW, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp3/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.574      0.755      0.689       0.68
#                  Anger       2745        527      0.732      0.626      0.737      0.722
# ...

# %% [markdown]
# **Experiment 4** Epochs to 20

# %%
# !cat yolov5/data/hyps/hyp_my-4.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.001  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 20 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer Adam --hyp yolov5/data/hyps/hyp_my-4.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my-4.yaml, epochs=20, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp4/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.617      0.744      0.719       0.71
#                  Anger       2745        527      0.708      0.617      0.737      0.726
# ...

# %% [markdown]
# **Experiment 5** Mosaic to 1.0

# %%
# !cat yolov5/data/hyps/hyp_my-5.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.001  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 10 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer Adam --hyp yolov5/data/hyps/hyp_my-5.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my-5.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp5/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp5/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.598       0.71       0.69       0.68
#                  Anger       2745        527      0.711      0.545      0.684       0.67
# ...

# %% [markdown]
# **Experiment 6** learning rate (lr0) to 0.01

# %%
# !cat yolov5/data/hyps/hyp_my-6.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
# # Hyperparameters for low-augmentation COCO training from scratch
# # python train.py --batch 64 --cfg yolov5n6.yaml --weights '' --data coco.yaml --img 640 --epochs 300 --linear
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.01  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# ...

# %%
import time
start_time = time.time()

# !python yolov5/train.py --batch 16 --epochs 10 --weights yolov5/weights/yolov5l.pt --cfg yolov5/models/yolov5l.yaml --data yolov5/data/FER_CREMA_D.yaml --img 512 --device 0 --optimizer Adam --hyp yolov5/data/hyps/hyp_my-6.yaml

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5/weights/yolov5l.pt, cfg=yolov5/models/yolov5l.yaml, data=yolov5/data/FER_CREMA_D.yaml, hyp=yolov5/data/hyps/hyp_my-6.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# ...

# %%
import time
start_time = time.time()

# !python yolov5/val-modified.py --weights yolov5/runs/train/exp6/weights/best.pt --data yolov5/data/FER_CREMA_D.yaml --img 512 --save-txt

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time}")
# Out:
# val-modified: data=yolov5/data/FER_CREMA_D.yaml, weights=['yolov5/runs/train/exp6/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8112MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46135203 parameters, 0 gradients
# val: Scanning /home/ext-shirokov-m@ad.speechpro.com/shirokov/AdvancedML/CREMA_D_
#                  Class     Images  Instances          P          R      mAP50
#                    all       2745       2745      0.399      0.752      0.505      0.486
#                  Anger       2745        527      0.259      0.674      0.335      0.318
# ...
